# %% [markdown]
# ## Load data from Wiki English corpus

# %%
! pip install datasets

# %%
from datasets import load_dataset
ds = load_dataset("sentence-transformers/wikipedia-en-sentences")

# %%
dataset_train = ds['train']

# %%
dataset_train.to_csv('dataset/wikipedia-en-sentences.csv', index=False)
# Out:
# Creating CSV from Arrow format:   0%|          | 0/7872 [00:00<?, ?ba/s]
# 944555336

# %%
dataset_train
# Out:
# Dataset({
#     features: ['sentence'],
#     num_rows: 7871825
# })

# %% [markdown]
# ## Other Datasets

# %%
from datasets import load_dataset

ds_high_quality = load_dataset("agentlans/high-quality-english-sentences")

# %%
import pandas as pd

# Ensure hq_train is a pandas DataFrame with a single column named "text"
hq_train = pd.DataFrame(ds_high_quality['train'], columns=["text"])

# %%
len(hq_train)
hq_train=hq_train[:25000]

# %%
# hq_train = ds_high_quality['train']
hq_train.to_csv('dataset/train.csv', index=False)

# %%
# Use a pipeline as a high-level helper
from transformers import pipeline

# Load model directly
from transformers import AutoTokenizer, AutoModelForCausalLM

tokenizer = AutoTokenizer.from_pretrained("meta-llama/Llama-3.2-1B")
model = AutoModelForCausalLM.from_pretrained("meta-llama/Llama-3.2-1B")
# Out:
# config.json:   0%|          | 0.00/843 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.47G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/185 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/50.5k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.09M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/301 [00:00<?, ?B/s]
# Device set to use cuda:0

# %% [markdown]
# * https://github.com/ken-ando/WikiSQE
# * https://github.com/google-research-datasets/wiki-split
